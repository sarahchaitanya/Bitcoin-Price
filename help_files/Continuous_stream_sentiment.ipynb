# %%
# import tweepy library for twitter api access and textblob libary for sentiment analysis
import csv
import tweepy
import numpy as np
from textblob import TextBlob
import datetime
import time

def main():

    # set twitter api credentials
    consumer_key= 'sSSqbpPzL3ZhlP01rrRUcJ3Xa'
    consumer_secret= 'qtJu2ASSVjVOOU15zzhueqpajzgWMgDNVPkRvQQQDKL4WtnFP0'
    access_token='1496847141527977997-2TbGk7n9Np6hD9wtX5T7qydAvMr7rx'
    access_token_secret='LnBBfQKUwIQvipXf5lKoIP5zKzbD4mqRRtTGXOU51SVKJ'

    # set path of csv file to save sentiment stats
    path = 'live_tweet.csv'
    f = open(path,"a")
    f1 = open('tweet_data','a')
    # access twitter api via tweepy methods
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#     auth.set_access_token(access_token, access_token_secret)
    twitter_api = tweepy.API(auth)

    while True:

        # fetch tweets by keywords
        tweets = twitter_api.search_tweets(q='bitcoin')#['bitcoin, price, crypto']) #count=100

        # get polarity
        polarity = get_polarity(tweets,f1)
        sentiment = np.mean(polarity)

        # save sentiment data to csv file
        f.write(str(sentiment))
        f.write(","+datetime.datetime.now().strftime("%y-%m-%d-%H-%M"))
        f.write("\n")
        f.flush()
        time.sleep(60)
    

def get_polarity(tweets,f):
    # run polarity analysis on tweets

    tweet_polarity = []

    for tweet in tweets:
        f.write(tweet.text+"\n")
        analysis = TextBlob(tweet.text)
        tweet_polarity.append(analysis.sentiment.polarity)

    return tweet_polarity

main()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-10-9712b5beb8ef> in <module>
#      53     return tweet_polarity
#      54
# ---> 55 main()
#
# <ipython-input-10-9712b5beb8ef> in main()
#      30
#      31         # get polarity
# ---> 32         polarity = get_polarity(tweets,f1)
#      33         sentiment = np.mean(polarity)
#      34
#
# <ipython-input-10-9712b5beb8ef> in get_polarity(tweets, f)
#      47
#      48     for tweet in tweets:
# ---> 49         f.write(tweet.text)
#      50         analysis = TextBlob(tweet.text)
#      51         tweet_polarity.append(analysis.sentiment.polarity)
#
# ~\anaconda3\envs\arth\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ...

# %% [markdown]
# ## Handling emojis
# https://medium.com/geekculture/text-preprocessing-how-to-handle-emoji-emoticon-641bbfa6e9e7

# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
consumer_key= 'sSSqbpPzL3ZhlP01rrRUcJ3Xa'
consumer_secret= 'qtJu2ASSVjVOOU15zzhueqpajzgWMgDNVPkRvQQQDKL4WtnFP0'
access_token='1496847141527977997-2TbGk7n9Np6hD9wtX5T7qydAvMr7rx'
access_token_secret='LnBBfQKUwIQvipXf5lKoIP5zKzbD4mqRRtTGXOU51SVKJ'

# %%
import tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
# tweets = api.search_tweets(q='bitcoin')#['bitcoin, price, crypto']) #count=100
search_term='#bitcoin -filter:retweets'
tweets = tweepy.Cursor(api.search_tweets,q=search_term,lang='en',since='2020-01-01',tweet_mode='extended').items(2000)

# %%
type(tweets)
# Out:
# tweepy.cursor.ItemIterator

# %%
dir(tweets)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'current_page',
#  'limit',
#  'next',
#  'num_tweets',
#  'page_index',
#  'page_iterator',
#  'prev']

# %%
print(tweets.next)
# Out:
# <bound method ItemIterator.next of <tweepy.cursor.ItemIterator object at 0x0000014DCD996248>>

# %%
for tweet in tweets:
    print(tweet)
# Out:
# Unexpected parameter: since
# ...

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @AliAzad90: @BluesparrowC @coinbase @BlueSparrowETH How amazing can it be?  #Bluesparrow Native Token for Decentralized Exchange with fo…
# RT @PanasheTapy: Block reports Q4 revenue of $4.08B, up 29% YoY, and $1.96B in Cash App bitcoin revenue, up 12% YoY; bitcoin revenue hit $1…
# RT @natbrunell: Try to take a country off SWIFT in a #Bitcoin world and let’s see what happens
# RT @Dennis_Porter_: If you hate #Bitcoin because Putin might use it, you should also hate the internet, GPS, cars, airplanes, and oxygen.
# have y'all heard of free bitcoin.  Amazing platform ive been using it for yrs. It's no gimmick literally you don't… https://t.co/sjIFO0a32e
# RT @mirafzal_iran: @BluesparrowC @BitcoinMagazine @nayibbukele @chivopets @BlueSparrowETH I will never ask you, to buy or sell, i’m just as…
# RT @yassineARK: Your college economics professor doesn’t know why Bitcoin is up today.
# RT @BitcoinMagazine: Gold is now back to its 2011 all time high.
#
# ...

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('europe refugees').setSince("2015-05-01").setUntil("2015-09-30").setMaxTweets(1)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0] 
print(tweet.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-dcd53b8577c8> in <module>
# ----> 1 tweetCriteria = got.manager.TweetCriteria().setQuerySearch('europe refugees').setSince("2015-05-01").setUntil("2015-09-30").setMaxTweets(1)
#       2 tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
#       3 print(tweet.text)
#
# AttributeError: module 'got' has no attribute 'manager'

# %%
import got

# %%
print(dir(got))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']

# %%
pip install got
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# ...
#   Running setup.py clean for lxml
# ...
#   Created wheel for pyquery: filename=pyquery-1.2.10-py3-none-any.whl size=19234 sha256=4fa001699ba37e76f324313e3f07dd2f926cbc5c1b5ef84c8186ed185c4db1e6
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\e3\fe\e6\9af802bdf9242644939cae3ac1015702a016539fef97f3448f
# Successfully built pyquery
# Failed to build lxml
# ...
#     Running setup.py install for lxml: started
#     Running setup.py install for lxml: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
# ...

# %% [markdown]
# ## Getting twitter data with snscrape library

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Bitcoin since:2021-01-01 until:2021-01-05').get_items()):
    tweets_list2.append([tweet.date, tweet.id, tweet.content])# tweet.user.username])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text'])# 'Username'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-03830c829896> in <module>
#       6
#       7 # Using TwitterSearchScraper to scrape data and append tweets to list
# ----> 8 for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Bitcoin since:2021-01-01 until:2021-01-05').get_items()):
#       9     tweets_list2.append([tweet.date, tweet.id, tweet.content])# tweet.user.username])
#      10
#
# ~\anaconda3\envs\arth\lib\site-packages\snscrape\modules\twitter.py in get_items(self)
#     166                         params['spelling_corrections'] = '1'
#     167                         params['ext'] = 'mediaStats%2CcameraMoment'
# --> 168                         r = self._get('https://api.twitter.com/2/search/adaptive.json', params = params, headers = headers, responseOkCallback = self._check_scroll_response)
# ...

# %%
tweets_df2
# Out:
#                      Datetime             Tweet Id  \
# 0   2020-07-30 23:57:02+00:00  1288986997143601152
# 1   2020-07-30 23:44:04+00:00  1288983731122966534
# 2   2020-07-30 22:40:40+00:00  1288967774795116550
# 3   2020-07-30 22:37:18+00:00  1288966929236066309
# 4   2020-07-30 22:15:36+00:00  1288961467555950592
# ..                        ...                  ...
# 496 2020-07-24 06:56:33+00:00  1286555854838407168
# 497 2020-07-24 06:20:17+00:00  1286546728041295872
# 498 2020-07-24 06:18:19+00:00  1286546232538796034
# 499 2020-07-24 06:14:19+00:00  1286545224811057153
# 500 2020-07-24 06:01:21+00:00  1286541963743944704
#
#                                                   Text
# 0    @SiBuduh @langoinstitute do you know the Ko wo...
# 1    @RockstarGames Any idea if the elephant rifle ...
# 2    @realDonaldTrump Trump just keeps ignoring the...
# 3    @cslogan88 Famous 19th century song from Engla...
# 4    Based on “The Tower of the Elephant” and show ...
# ...

# %%
tweets_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  501 non-null    datetime64[ns, UTC]
#  1   Tweet Id  501 non-null    int64
#  2   Text      501 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(1), object(1)
# memory usage: 11.9+ KB

# %%
tweets_df2['Date'] = tweets_df2['Datetime'].dt.date
tweets_df2.head()
# Out:
#                    Datetime             Tweet Id  \
# 0 2020-07-30 23:57:02+00:00  1288986997143601152
# 1 2020-07-30 23:44:04+00:00  1288983731122966534
# 2 2020-07-30 22:40:40+00:00  1288967774795116550
# 3 2020-07-30 22:37:18+00:00  1288966929236066309
# 4 2020-07-30 22:15:36+00:00  1288961467555950592
#
#                                                 Text        Date
# 0  @SiBuduh @langoinstitute do you know the Ko wo...  2020-07-30
# 1  @RockstarGames Any idea if the elephant rifle ...  2020-07-30
# 2  @realDonaldTrump Trump just keeps ignoring the...  2020-07-30
# 3  @cslogan88 Famous 19th century song from Engla...  2020-07-30
# 4  Based on “The Tower of the Elephant” and show ...  2020-07-30

# %%
ddd2 = tweets_df2.groupby("Date")

# %%
keys = []
for key in ddd2.groups.keys():
    keys.append(key)

# %%
keys
# Out:
# [datetime.date(2020, 7, 24),
#  datetime.date(2020, 7, 25),
#  datetime.date(2020, 7, 26),
#  datetime.date(2020, 7, 27),
#  datetime.date(2020, 7, 28),
#  datetime.date(2020, 7, 29),
#  datetime.date(2020, 7, 30)]

# %%
tweets3 = ddd2.get_group(keys[0])['Text']
# type(ddd2.get_group(keys[0]))

# %%
from textblob import TextBlob
def get_polarity(tweets):
    # run polarity analysis on tweets

    tweet_polarity = []

    for tweet in tweets:
#         f.write(tweet.text+"\n")
        analysis = TextBlob(tweet)#.text)
        tweet_polarity.append(analysis.sentiment.polarity)

    return tweet_polarity

# %%
for i in tweets3[:3]:
    print(i)
# Out:
# @MysterySolvent An Elephant missing its trunk! @realDonaldTrump let the whole world know he has the capability to pick one out with a trunk.
# The unholy shininess of your labial facial folds disgusts and fascinates me. I imagine when you eat it sounds like an elephant sucking up mucus with its trunk.  Why doesn’t your skin fit @senatemajldr https://t.co/aPfMDfMk0X
# Twitter i DON'T want to see a baby elephant gunned down in cold blood for sport and NO i don't want to see a dog being fried alive.what the FUCK thes images should be banned they are SO SO upsetting..its awful humans are awful..so terrible..STOP STOP STOP

# %%
polarity_list = get_polarity(tweets3)

# %%
polarity_list
#https://www.analyticsvidhya.com/blog/2021/10/making-natural-language-processing-easy-with-textblob/#h2_5
# Out:
# [-0.024999999999999994,
#  0.2,
#  -0.5388888888888889,
#  0.14583333333333337,
#  0.0,
#  -0.35000000000000003,
#  0.0,
#  0.0529100529100529,
#  -0.3333333333333333,
#  0.0,
#  0.0,
#  1.0,
#  0.3711111111111111,
#  0.21666666666666667,
#  -0.30000000000000004,
#  -0.4,
#  0.1278409090909091,
#  -0.3999999999999999,
#  0.1619047619047619,
#  0.0,
#  0.1228422619047619,
#  0.13333333333333333,
#  0.0,
#  0.2125,
#  0.004151404151404149,
#  -0.21875,
#  0.22999999999999998,
#  -0.546875,
#  0.15000000000000002,
#  0.37857142857142856,
#  0.22142857142857145,
#  0.5,
#  0.14285714285714285,
#  0.11391941391941392,
#  -0.1,
#  0.12222222222222223,
#  0.0275,
#  -0.25,
#  0.013888888888888895,
#  0.15,
#  0.575,
#  0.10714285714285714,
#  0.0,
#  0.25,
#  0.26666666666666666,
#  0.39999999999999997,
#  -0.024999999999999967,
#  0.3333333333333333,
#  -0.2738095238095238,
#  0.125,
#  0.2464285714285714,
#  0.03749999999999999,
#  0.0,
#  0.0,
#  -0.4222222222222222,
#  0.375,
# ...

# %%
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

l = pd.date_range(start="2020-01-01",end="2020-12-31"). to_pydatetime(). tolist()

tweets_list2 = []
for tweet in (sntwitter.TwitterSearchScraper('bitcoin since:'+str(l[0])+' until:'+str(l[1])).get_items()):
    tweets_list2.append([tweet.date, tweet.id, tweet.content])
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text'])

# %%
# tweets_df2.head()
tweets_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  351 non-null    datetime64[ns, UTC]
#  1   Tweet Id  351 non-null    int64
#  2   Text      351 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(1), object(1)
# memory usage: 8.4+ KB

# %%
print(str(l[1]))
# Out:
# 2020-01-02 00:00:00

# %%
get_polarity(tweets_df2[:3])
# Out:
# [0.0, 0.0, 0.0]

# %%
tweet = 'Bitcoin prices are high'#using high,down polarity is not 0,but with using incresing,decresing it is 0
analysis = TextBlob(tweet)#.text)
print(analysis.sentiment)
# Out:
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
l = pd.date_range(start="2021-04-30",end="2021-05-30"). to_pydatetime().tolist()
# str(l[0].date())

# tweets_list = []
tweets_pol = []
for i in range(len(l)-1):
    print("for loop")
    tweets_list = []
# for i in pd.date_range(start="2020-01-01",end="2020-03-30"). to_pydatetime():
    for tweet in (sntwitter.TwitterSearchScraper('Bitcoin since:'+str(l[i])+' until:'+str(l[i+1])).get_items()):
        tweets_list.append([tweet.date, tweet.content])# tweet.user.username])

    tweets_df = pd.DataFrame(tweets_list,columns=['Datetime','Text'])
    length = len(tweets_list)
#     print(tweets_df.head())
#     print()
    pol_sub = get_polarity(tweets_df['Text'])
    print(pol_sub[:3])
    if length != 0:
        tweets_pol.append([l[i],sum(pol_sub)])#appending date and polarity of tweets
    else:
        tweets_pol.append([l[i],0])
# Creating a dataframe from the tweets list above
tweets_df3 = pd.DataFrame(tweets_pol, columns=['Datetime', 'pol']) # 'Username'])
tweets_df2 = tweets_df2.append(tweets_df3,ignore_index=True)
# Out:
# for loop
# [0.0, 0.5, 0.0]
# for loop
# [0.0, 0.5, 0.5]
# for loop
# [0.5, 0.5, 0.0]
# for loop
# [0.0, 0.0, 0.0]
# for loop
# [-0.08333333333333333, 0.3, 0.3]
# for loop
# [0.15, 0.0, 0.5]
# for loop
# [0.0, 0.0, 0.0]
# for loop
# [0.12409090909090909, 0.5, 0.0]
# for loop
# [0.0, 0.0, 0.0]
# for loop
# [0.0, 0.125, 0.0]
# for loop
# [0.0, 0.0, 0.0]
# for loop
# [0.0, 0.5, 0.0]
# for loop
# [0.3, 0.3, 0.3]
# for loop
# [0.0, 0.0, 0.1]
# for loop
# [0.015, 0.0, 0.25]
# for loop
# [0.0, -0.065, 0.0]
# for loop
# [0.0, 0.0, -0.18333333333333335]
# for loop
# [0.0, 0.0, 0.0]
# for loop
# [0.0, 0.26666666666666666, 0.0]
# for loop
# [0.0, 0.0, -0.15555555555555559]
# for loop
# [0.15, 0.15, 0.15]
# for loop
# [0.05, -0.025, -0.025]
# for loop
# ...

# %%
# dd = pd.DataFrame(pd.date_range(start="2021-01-01",end="2021-01-30"). to_pydatetime().tolist())
# tweets_df2['Datetime'] = dd[0]
tweets_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  119 non-null    datetime64[ns]
#  1   pol       119 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.0 KB

# %%
tweets_df2 = tweets_df2.append(tweets_df3,ignore_index=True)

# %%
# for x in [1,2,3]:
#     tirumala = []
#     for y in [4,5,6]:
#         tirumala.append(y)
#     print(tirumala)
a = tweets_df2
b = tweets_df3

# %%
tweets_df2.tail()
# Out:
#      Datetime        pol
# 84 2021-03-26  27.967884
# 85 2021-03-27  19.913267
# 86 2021-03-28  16.185114
# 87 2021-03-29  15.648794
# 88 2021-03-30  28.871529

# %%
tweet_file = tweets_df2.to_csv("tweet_file.csv")

# %%
tweet_file.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-59cd22e9715a> in <module>
# ----> 1 tweet_file.tail()
#
# AttributeError: 'NoneType' object has no attribute 'tail'

# %%
tweets_df2.to_csv(r'.\file4.csv', index=False)

# %%
import pandas as pd
tweets_df2 = pd.read_csv("file3.csv")

# %%
tweets_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  119 non-null    float64
#  1   Datetime    366 non-null    object
#  2   pol         366 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 8.7+ KB

# %%
tweets_df2.tail()
# Out:
#      Unnamed: 0             Datetime        pol
# 361         NaN  2021-12-27 00:00:00  19.171833
# 362         NaN  2021-12-28 00:00:00  16.132080
# 363         NaN  2021-12-29 00:00:00  11.595228
# 364         NaN  2021-12-30 00:00:00   8.413339
# 365         NaN  2021-12-31 00:00:00  13.970676

# %%
sri = pd.date_range(start="2021-01-01",end="2021-12-31"). to_pydatetime()

# %%
type(sri)
# Out:
# numpy.ndarray

# %%
sri
# Out:
# array([datetime.datetime(2021, 1, 1, 0, 0),
#        datetime.datetime(2021, 1, 2, 0, 0),
#        datetime.datetime(2021, 1, 3, 0, 0),
#        datetime.datetime(2021, 1, 4, 0, 0),
#        datetime.datetime(2021, 1, 5, 0, 0),
#        datetime.datetime(2021, 1, 6, 0, 0),
#        datetime.datetime(2021, 1, 7, 0, 0),
#        datetime.datetime(2021, 1, 8, 0, 0),
#        datetime.datetime(2021, 1, 9, 0, 0),
#        datetime.datetime(2021, 1, 10, 0, 0),
#        datetime.datetime(2021, 1, 11, 0, 0),
#        datetime.datetime(2021, 1, 12, 0, 0),
#        datetime.datetime(2021, 1, 13, 0, 0),
#        datetime.datetime(2021, 1, 14, 0, 0),
#        datetime.datetime(2021, 1, 15, 0, 0),
#        datetime.datetime(2021, 1, 16, 0, 0),
#        datetime.datetime(2021, 1, 17, 0, 0),
#        datetime.datetime(2021, 1, 18, 0, 0),
#        datetime.datetime(2021, 1, 19, 0, 0),
#        datetime.datetime(2021, 1, 20, 0, 0),
#        datetime.datetime(2021, 1, 21, 0, 0),
# ...

# %%
tweets_df2['time'] = sri
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-deb5a33648ab> in <module>
# ----> 1 tweets_df2['time'] = sri
#
# ~\anaconda3\envs\arth\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\arth\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3237         """
#    3238         self._ensure_valid_index(value)
# -> 3239         value = self._sanitize_column(key, value)
#    3240         NDFrame._set_item(self, key, value)
#    3241
#
# ~\anaconda3\envs\arth\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3894
#    3895             # turn me into an ndarray
# ...
